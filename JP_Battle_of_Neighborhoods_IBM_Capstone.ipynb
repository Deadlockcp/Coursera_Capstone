# %% [markdown]
# # The Battle of the Neighborhoods

# %% [markdown]
# ## IBM Applied Data Science Capstone Project

# %% [markdown]
# ### Jack Perng

# %% [markdown]
# ## Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
#
# 1. [Introduction](#intro)
#
# 2. [Data](#data)
#
# 3. [Methodology](#method)
#
# 4. [Results](#results)
#
# 5. [Discussion](#discussion)
#
# 6. [Conclusion](#conclusion)
#
#
#
# </font>
# </div>

# %% [markdown]
# ## 1. Introduction
# <a id = "intro"></a>

# %% [markdown]
# **Business Problem**: If someone just obtained their California acupuncture license and resided in San Jose, where would be a good location to setup their practice? <br>
#
# The idea is to explore the San Jose neighborhoods, according to ZIP code, based on the follow factors that may be related to business growth:
# 1. Population<br>
# 2. Per capita income <br>
# 3. Existing competition <br>
# 4. Crime rate <br>
# 5. Unemployment rate <br>
# 6. Bachelor degree percentage <br>
# 7. Median home price <br>
#
# The neighborhoods would be clustered via **k-means clustering**, analyzed and compared. The goal is to identify, via the clustered results, potential neighborhood candidates to start an acupuncture clinic in.

# %% [markdown]
# ## 2. Data
# <a id = "data"></a>

# %% [markdown]
# **Data Sources**: The data for the project would come from the various sources:
#
#
# 1. Kaggle dataset "US Wages via Zipcode", containing the following information: <br>
# a. U.S. ZIP codes <br>
# b. Geographic coordinates <br>
# c. Estimated Population <br>
# d. Total Wages <br>
# From this dataset, the relevant data subset for San Jose, CA can be extracted. In addition, the per capita income can be calculated from. <br> (https://www.kaggle.com/pavansanagapati/us-wages-via-zipcode)
# 2. Foursquare location data, which will be used to find and locate the acupuncturists in the San Jose area. The results are used as the metric for existing competition in the same ZIP code.
#
# 3. ADT Security Services. The website contains an ADT Crime Map which provides the crime rate of each ZIP code. The "Total Crime" rate metric is selected.
#
# 4. City-Data. The website provides the following data of interest:<br>
# a. Unemployment rate <br>
# b. Bachelor degree or higher percentage <br>
# for population 25 and over.
#
# 5. Zillow contains data on typical home prices based on ZIP code. The latest home prices at the time of completing this project, published on 05/31/2020, are used.
#
# The combined information of all the data described above provide the input to the clustering algorithm model.

# %% [markdown]
# ## 3. Methodology
# <a id = "method"></a>

# %% [markdown]
# ### 3.1 Kaggle Dataset

# %% [markdown]
# Import pandas

# %%
import pandas as pd

# %% [markdown]
# Read the Kaggle dataset into DataFrame

# %%
sj_zip_wages_df = pd.read_csv('free-zipcode-database-Primary.csv')
sj_zip_wages_df.head()
# Out:
#    Zipcode ZipCodeType      City State LocationType    Lat   Long  \
# 0      705    STANDARD  AIBONITO    PR      PRIMARY  18.14 -66.26
# 1      610    STANDARD    ANASCO    PR      PRIMARY  18.28 -67.14
# 2      611      PO BOX   ANGELES    PR      PRIMARY  18.28 -66.79
# 3      612    STANDARD   ARECIBO    PR      PRIMARY  18.45 -66.73
# 4      601    STANDARD  ADJUNTAS    PR      PRIMARY  18.16 -66.72
#
#             Location  Decommisioned  TaxReturnsFiled  EstimatedPopulation  \
# 0  NA-US-PR-AIBONITO          False              NaN                  NaN
# 1    NA-US-PR-ANASCO          False              NaN                  NaN
# 2   NA-US-PR-ANGELES          False              NaN                  NaN
# 3   NA-US-PR-ARECIBO          False              NaN                  NaN
# 4  NA-US-PR-ADJUNTAS          False              NaN                  NaN
#
#    TotalWages
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
sj_zip_wages_df.shape
# Out:
# (42522, 12)

# %% [markdown]
# Clean up the Dataframe by selecting the relevant entries of San Jose, CA. Also remove the ZIP Codes that are PO Boxes. Lastly, double-check that the ZIP Code is not decommisioned.

# %%
sj_zip_wages_df = sj_zip_wages_df[sj_zip_wages_df.City == 'SAN JOSE']
sj_zip_wages_df = sj_zip_wages_df[sj_zip_wages_df.State == 'CA']
sj_zip_wages_df = sj_zip_wages_df[sj_zip_wages_df.ZipCodeType != 'PO BOX']
sj_zip_wages_df = sj_zip_wages_df[sj_zip_wages_df.Decommisioned == False]

# %%
print(sj_zip_wages_df.shape)
sj_zip_wages_df.head()
# Out:
# (36, 12)
#        Zipcode ZipCodeType      City State LocationType    Lat    Long  \
# 23873    95101    STANDARD  SAN JOSE    CA      PRIMARY  37.38 -121.89
# 23878    95110    STANDARD  SAN JOSE    CA      PRIMARY  37.34 -121.90
# 23879    95111    STANDARD  SAN JOSE    CA      PRIMARY  37.28 -121.83
# 23880    95112    STANDARD  SAN JOSE    CA      PRIMARY  37.34 -121.88
# 23881    95113    STANDARD  SAN JOSE    CA      PRIMARY  37.33 -121.89
#
#                 Location  Decommisioned  TaxReturnsFiled  EstimatedPopulation  \
# 23873  NA-US-CA-SAN JOSE          False              NaN                  NaN
# 23878  NA-US-CA-SAN JOSE          False           7460.0              12621.0
# 23879  NA-US-CA-SAN JOSE          False          23302.0              43578.0
# 23880  NA-US-CA-SAN JOSE          False          21203.0              34111.0
# 23881  NA-US-CA-SAN JOSE          False            781.0               1049.0
#
#         TotalWages
# 23873          NaN
# 23878  366468568.0
# 23879  866020686.0
# 23880  891795651.0
# 23881   37924110.0

# %% [markdown]
# Select the relevant columns

# %%
sj_zip_wages_df = sj_zip_wages_df[['Zipcode', 'Lat', 'Long', 'EstimatedPopulation', 'TotalWages']]
sj_zip_wages_df
# Out:
#        Zipcode    Lat    Long  EstimatedPopulation    TotalWages
# 23873    95101  37.38 -121.89                  NaN           NaN
# 23878    95110  37.34 -121.90              12621.0  3.664686e+08
# 23879    95111  37.28 -121.83              43578.0  8.660207e+08
# 23880    95112  37.34 -121.88              34111.0  8.917957e+08
# 23881    95113  37.33 -121.89               1049.0  3.792411e+07
# 23883    95116  37.35 -121.85              35357.0  6.238882e+08
# 23884    95117  37.31 -121.96              22030.0  6.661914e+08
# 23885    95118  37.25 -121.88              26249.0  8.777164e+08
# 23886    95119  37.22 -121.78               8171.0  2.887622e+08
# 23887    95120  37.19 -121.83              33486.0  1.704123e+09
# 23888    95121  37.30 -121.80              30427.0  7.641766e+08
# 23889    95122  37.33 -121.83              41936.0  7.011536e+08
# 23890    95123  37.23 -121.82              50481.0  1.634682e+09
# 23891    95124  37.25 -121.92              39234.0  1.515281e+09
# 23892    95125  37.29 -121.88              41048.0  1.782530e+09
# 23893    95126  37.32 -121.91              23076.0  8.414504e+08
# 23894    95127  37.37 -121.75              46641.0  1.064356e+09
# 23895    95128  37.31 -121.93              25327.0  8.363117e+08
# 23896    95129  37.30 -122.00              32839.0  1.371049e+09
# 23897    95130  37.28 -121.98              10841.0  3.945737e+08
# 23898    95131  37.38 -121.90              24403.0  9.194561e+08
# 23899    95132  37.42 -121.77              34344.0  1.054567e+09
# 23900    95133  37.37 -121.86              20337.0  5.406107e+08
# 23901    95134  37.42 -121.94              12670.0  6.541769e+08
# 23902    95135  37.25 -121.67              17221.0  7.246593e+08
# 23903    95136  37.27 -121.84              35078.0  1.177501e+09
# 23904    95138  37.24 -121.73              15421.0  8.911679e+08
# 23905    95139  37.21 -121.75               5634.0  2.056586e+08
# 23907    95141  37.17 -121.75                  NaN           NaN
# 23908    95148  37.33 -121.77              37541.0  1.141396e+09
# 23925    95190  37.37 -121.90                  NaN           NaN
# 23926    95191  37.32 -121.91                  NaN           NaN
# 23927    95192  37.34 -121.89                  NaN           NaN
# 23928    95193  37.24 -121.83                  NaN           NaN
# 23929    95194  37.34 -121.88                  NaN           NaN
# 23930    95196  37.33 -121.89                  NaN           NaN

# %% [markdown]
# Lastly, remove the ZIP codes with missing values (NaN). Reset indices.

# %%
sj_zip_wages_df.dropna(axis = 0, inplace = True)
sj_zip_wages_df.reset_index(drop = True, inplace = True)
print(sj_zip_wages_df.shape)
sj_zip_wages_df.head()
# Out:
# (28, 5)
#    Zipcode    Lat    Long  EstimatedPopulation   TotalWages
# 0    95110  37.34 -121.90              12621.0  366468568.0
# 1    95111  37.28 -121.83              43578.0  866020686.0
# 2    95112  37.34 -121.88              34111.0  891795651.0
# 3    95113  37.33 -121.89               1049.0   37924110.0
# 4    95116  37.35 -121.85              35357.0  623888214.0

# %% [markdown]
# Add "per capita wages" column by dividing the TotalWages by EstimatedPopulation.

# %%
sj_zip_wages_df['PerCapitaWages'] = sj_zip_wages_df['TotalWages']/sj_zip_wages_df['EstimatedPopulation']
sj_zip_wages_df.head()
# Out:
#    Zipcode    Lat    Long  EstimatedPopulation   TotalWages  PerCapitaWages
# 0    95110  37.34 -121.90              12621.0  366468568.0    29036.412963
# 1    95111  37.28 -121.83              43578.0  866020686.0    19872.887374
# 2    95112  37.34 -121.88              34111.0  891795651.0    26143.931606
# 3    95113  37.33 -121.89               1049.0   37924110.0    36152.631077
# 4    95116  37.35 -121.85              35357.0  623888214.0    17645.394519

# %%
print("The are", sj_zip_wages_df.shape[0], "ZIP codes\n")
print(list(sj_zip_wages_df['Zipcode']))
# Out:
# The are 28 ZIP codes
#
# [95110, 95111, 95112, 95113, 95116, 95117, 95118, 95119, 95120, 95121, 95122, 95123, 95124, 95125, 95126, 95127, 95128, 95129, 95130, 95131, 95132, 95133, 95134, 95135, 95136, 95138, 95139, 95148]

# %% [markdown]
# Import and install relevant packages.

# %%
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes 
import folium # map rendering library

import json # library to handle JSON files

from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

import numpy as np # library to handle data in a vectorized manner
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2020.6.20  |       hecda079_0         145 KB  conda-forge
#     certifi-2020.6.20          |   py36h9f0ad1d_0         151 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-2.0.0                |     pyh9f0ad1d_0          63 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         394 KB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-2.0.0-pyh9f0ad1d_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2020.4.5.2-hecda079_0 --> 2020.6.20-hecda079_0
#   certifi                         2020.4.5.2-py36h9f0ad1d_0 --> 2020.6.20-py36h9f0ad1d_0
#
#
#
# Downloading and Extracting Packages
# certifi-2020.6.20    | 151 KB    | ##################################### | 100%
# ca-certificates-2020 | 145 KB    | ##################################### | 100%
# geopy-2.0.0          | 63 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# Draw map of San Jose, CA

# %%
address = 'San Jose, CA'

geolocator = Nominatim(user_agent="sj_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of San Jose, CA are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of San Jose, CA are 37.3361905, -121.8905833.

# %%
# create map of San Jose using latitude and longitude values
map_sj = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(sj_zip_wages_df['Lat'], sj_zip_wages_df['Long'], sj_zip_wages_df['Zipcode'].astype(str)):  
                                                                            #  ^^
                                                                            # need to convert Zipcode to string to display properly 
    
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_sj)  
    
map_sj
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 3.2 Foursquare Location Data

# %%
import requests

# %% [markdown]
# Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'IH5AG3QTLSUDQCJ01DLXNF3I4NBHNJ0MHSODAIE1IGQSZS3K' # your Foursquare ID
CLIENT_SECRET = 'UBZ2GRFVDKJVI0YLC13PKS4L2CIMQ1CSX20Z4BOY5CYQ2KZD' # your Foursquare Secret
VERSION = '20190605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: IH5AG3QTLSUDQCJ01DLXNF3I4NBHNJ0MHSODAIE1IGQSZS3K
# CLIENT_SECRET:UBZ2GRFVDKJVI0YLC13PKS4L2CIMQ1CSX20Z4BOY5CYQ2KZD

# %%
search_query = 'Acupuncture'
radius = 16000
LIMIT = 500

# %%
url_acu = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    latitude, 
    longitude, 
    VERSION, 
    search_query, 
    radius, 
    LIMIT)

#url_acu1 = url_acu + "&offset=50"
url_acu
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=IH5AG3QTLSUDQCJ01DLXNF3I4NBHNJ0MHSODAIE1IGQSZS3K&client_secret=UBZ2GRFVDKJVI0YLC13PKS4L2CIMQ1CSX20Z4BOY5CYQ2KZD&ll=37.3361905,-121.8905833&v=20190605&query=Acupuncture&radius=16000&limit=500'

# %%
results = requests.get(url_acu).json()

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']
#print(venues)

# tranform venues into a dataframe
sj_acu_df = pd.json_normalize(venues)
sj_acu_df.head()
# Out:
#                          id                                              name  \
# 0  4ce1a79ef8a4a1438ddeebbc                               Nurture Acupuncture
# 1  58e178060e0a1e6dd8a4f3e3                    Charles Lin Acupuncture Clinic
# 2  51cb8d6d498e66b4ad36c053  Acupuncture Orthopedics & Natural Healing Center
# 3  58f1732e780eee3965948df0                                  Numo Acupuncture
# 4  51142233e4b07ef2ec1fd677            1-2-3 Acupuncture Clinic (Santa Clara)
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '52e81612bcbc57f1066b7a3b', 'name': 'A...  v-1594014279    False
# 1  [{'id': '52e81612bcbc57f1066b7a3b', 'name': 'A...  v-1594014279    False
# 2  [{'id': '52e81612bcbc57f1066b7a3b', 'name': 'A...  v-1594014279    False
# 3  [{'id': '52e81612bcbc57f1066b7a3b', 'name': 'A...  v-1594014279    False
# 4  [{'id': '52e81612bcbc57f1066b7a3b', 'name': 'A...  v-1594014279    False
#
#            location.address  location.lat  location.lng  \
# 0     1520 The Alameda #130     37.335472   -121.915164
# 1      475 N 1st St Ste 200     37.343643   -121.896553
# 2    259 Meridian Ave Ste 8     37.324388   -121.914624
# 3  1630 Oakland Rd Ste A110     37.381672   -121.894552
# 4    3700 Thomas Rd Ste 215     37.386284   -121.960762
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 37.33547199999999...               2177
# 1  [{'label': 'display', 'lat': 37.34364318847656...                983
# 2  [{'label': 'display', 'lat': 37.324388, 'lng':...               2500
# 3  [{'label': 'display', 'lat': 37.3816716, 'lng'...               5075
# 4  [{'label': 'display', 'lat': 37.386284, 'lng':...               8345
#
#   location.postalCode location.cc location.city location.state  \
# 0               95126          US      San Jose             CA
# 1               95112          US      San Jose             CA
# 2               95126          US      San Jose             CA
# 3               95131          US      San Jose             CA
# 4               95054          US   Santa Clara             CA
#
#   location.country                          location.formattedAddress  \
# 0    United States  [1520 The Alameda #130, San Jose, CA 95126, Un...
# 1    United States  [475 N 1st St Ste 200, San Jose, CA 95112, Uni...
# 2    United States  [259 Meridian Ave Ste 8, San Jose, CA 95126, U...
# 3    United States  [1630 Oakland Rd Ste A110, San Jose, CA 95131,...
# 4    United States  [3700 Thomas Rd Ste 215 (San Thomas EXP), Sant...
#
#   location.crossStreet venuePage.id
# 0                  NaN          NaN
# 1                  NaN          NaN
# 2                  NaN          NaN
# 3                  NaN          NaN
# 4       San Thomas EXP          NaN

# %%
sj_acu_df.shape
# Out:
# (50, 18)

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in sj_acu_df.columns if col.startswith('location.')] + ['id']
sj_acu_df_filtered = sj_acu_df.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
sj_acu_df_filtered['categories'] = sj_acu_df_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
sj_acu_df_filtered.columns = [column.split('.')[-1] for column in sj_acu_df_filtered.columns]

sj_acu_df_filtered.head()
# Out:
#                                                name     categories  \
# 0                               Nurture Acupuncture  Acupuncturist
# 1                    Charles Lin Acupuncture Clinic  Acupuncturist
# 2  Acupuncture Orthopedics & Natural Healing Center  Acupuncturist
# 3                                  Numo Acupuncture  Acupuncturist
# 4            1-2-3 Acupuncture Clinic (Santa Clara)  Acupuncturist
#
#                     address        lat         lng  \
# 0     1520 The Alameda #130  37.335472 -121.915164
# 1      475 N 1st St Ste 200  37.343643 -121.896553
# 2    259 Meridian Ave Ste 8  37.324388 -121.914624
# 3  1630 Oakland Rd Ste A110  37.381672 -121.894552
# 4    3700 Thomas Rd Ste 215  37.386284 -121.960762
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 37.33547199999999...      2177      95126  US
# 1  [{'label': 'display', 'lat': 37.34364318847656...       983      95112  US
# 2  [{'label': 'display', 'lat': 37.324388, 'lng':...      2500      95126  US
# 3  [{'label': 'display', 'lat': 37.3816716, 'lng'...      5075      95131  US
# 4  [{'label': 'display', 'lat': 37.386284, 'lng':...      8345      95054  US
#
#           city state        country  \
# 0     San Jose    CA  United States
# 1     San Jose    CA  United States
# 2     San Jose    CA  United States
# 3     San Jose    CA  United States
# 4  Santa Clara    CA  United States
#
#                                     formattedAddress     crossStreet  \
# 0  [1520 The Alameda #130, San Jose, CA 95126, Un...             NaN
# 1  [475 N 1st St Ste 200, San Jose, CA 95112, Uni...             NaN
# 2  [259 Meridian Ave Ste 8, San Jose, CA 95126, U...             NaN
# 3  [1630 Oakland Rd Ste A110, San Jose, CA 95131,...             NaN
# 4  [3700 Thomas Rd Ste 215 (San Thomas EXP), Sant...  San Thomas EXP
#
#                          id
# 0  4ce1a79ef8a4a1438ddeebbc
# 1  58e178060e0a1e6dd8a4f3e3
# 2  51cb8d6d498e66b4ad36c053
# 3  58f1732e780eee3965948df0
# 4  51142233e4b07ef2ec1fd677

# %% [markdown]
# Keep only venues that are in San Jose

# %%
sj_acu_df_filtered = sj_acu_df_filtered[sj_acu_df_filtered.city == 'San Jose']
sj_acu_df_filtered.reset_index(drop = True, inplace = True)
sj_acu_df_filtered
# Out:
#                                                  name          categories  \
# 0                                 Nurture Acupuncture       Acupuncturist
# 1                      Charles Lin Acupuncture Clinic       Acupuncturist
# 2    Acupuncture Orthopedics & Natural Healing Center       Acupuncturist
# 3                                    Numo Acupuncture       Acupuncturist
# 4                                         Acupuncture       Acupuncturist
# 5                                   Green Acupuncture      Massage Studio
# 6                                 Kim Wah Acupuncture       Acupuncturist
# 7              Vinh Quang Acupuncture & Chinese Herbs       Acupuncturist
# 8                                  Lokahi Acupuncture       Acupuncturist
# 9                      Zhu's Neuro-Acupuncture Center       Acupuncturist
# 10                               Red Pine Acupuncture       Acupuncturist
# 11                               Hong Wei Acupuncture       Acupuncturist
# 12                           Alice Acupuncture Center       Acupuncturist
# 13                             AAA Acupuncture Center  Alternative Healer
# 14                          Willow Glen Acupuncture/H       Acupuncturist
# 15                     Cornerstone Acupuncture Center       Acupuncturist
# 16  Victor Cheng Acupuncture and Traditional Chine...       Acupuncturist
# 17                                 Lokahi Acupuncture       Acupuncturist
# 18                         Lao Lao Acupuncture Center       Acupuncturist
# 19        East West Chiropractic & Acupuncture Clinic        Chiropractor
# 20                                  Evoke Acupuncture       Acupuncturist
# 21                        San Jose Acupuncture Center       Acupuncturist
# 22                            Living Room Acupuncture       Acupuncturist
# 23                                 LB Acupuncture inc       Acupuncturist
# 24                                   Park Acupuncture       Acupuncturist
# 25                   Qin Acupuncture and Herbs Center       Acupuncturist
# 26                Lotus Acupuncture & Wellness Center      Medical Center
# 27                                  Evoke Acupuncture       Acupuncturist
# 28                       Natural Wellness Acupuncture       Acupuncturist
# 29                       Dr. Mark Wilson  Acupuncture       Acupuncturist
# 30                        Acupressure And Acupuncture       Acupuncturist
# 31                                 Valley Acupuncture       Acupuncturist
# 32                                   Zhao Acupuncture       Acupuncturist
# 33                          Peter Hien Vo Acupuncture       Acupuncturist
# 34                         Chiropractic & Acupuncture        Chiropractor
#
#                              address        lat         lng  \
# 0              1520 The Alameda #130  37.335472 -121.915164
# 1               475 N 1st St Ste 200  37.343643 -121.896553
# 2             259 Meridian Ave Ste 8  37.324388 -121.914624
# 3           1630 Oakland Rd Ste A110  37.381672 -121.894552
# 4                                NaN  37.225533 -121.859755
# 5               265 Meridian Ave. #9  37.324160 -121.914230
# 6                      1818 Tully Rd  37.322895 -121.824707
# 7                      1001 Story RD  37.333230 -121.856727
# 8            259 Meridian Ave Ste 14  37.324516 -121.913934
# 9         1754 Technology Dr Ste 225  37.369337 -121.919080
# 10              1314 Lincoln Ave #2D  37.304841 -121.898004
# 11                   1630 Oakland Rd  37.381694 -121.894485
# 12                  527 S Bascom Ave  37.318465 -121.932040
# 13            1670 Westwood Dr Ste J  37.302460 -121.915771
# 14                 1058 Meridian Ave  37.305084 -121.913246
# 15                               NaN  37.327831 -121.936129
# 16            2211 Moorpark Ave #250  37.316483 -121.932671
# 17                               NaN  37.303230 -121.915950
# 18           1754 Technology Dr #128  37.369337 -121.919080
# 19                               NaN  37.321842 -121.943115
# 20                               NaN  37.306012 -121.951616
# 21                 1836 Hamilton Ave  37.294083 -121.918839
# 22          1630 Oakland Rd Ste A110  37.381694 -121.894485
# 23             860 S Winchester Blvd  37.310243 -121.949615
# 24            2375 Zanker Rd Ste 250  37.384846 -121.921646
# 25                    1879 Lundy Ave  37.392659 -121.891629
# 26                    1885 Lundy Ave  37.393173 -121.891637
# 27                               NaN  37.306021 -121.951624
# 28   1101 S Winchester Blvd Ste N267  37.305824 -121.951685
# 29  1101 S. Winchester Ste. Ste L239  37.306313 -121.951474
# 30                  5710 Cahalan Ave  37.248140 -121.846514
# 31            1087 S Winchester Blvd  37.307213 -121.950691
# 32                               NaN  37.306119 -121.951040
# 33                               NaN  37.308765 -121.814087
# 34                               NaN  37.312370 -121.809383
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 37.33547199999999...      2177      95126
# 1   [{'label': 'display', 'lat': 37.34364318847656...       983      95112
# 2   [{'label': 'display', 'lat': 37.324388, 'lng':...      2500      95126
# 3   [{'label': 'display', 'lat': 37.3816716, 'lng'...      5075      95131
# 4   [{'label': 'display', 'lat': 37.22553319504755...     12617      95120
# 5   [{'label': 'display', 'lat': 37.32416, 'lng': ...      2484      95126
# 6   [{'label': 'display', 'lat': 37.32289505004883...      6016      95122
# 7   [{'label': 'display', 'lat': 37.33323, 'lng': ...      3014        NaN
# 8   [{'label': 'display', 'lat': 37.32451639011752...      2441      95126
# 9   [{'label': 'display', 'lat': 37.369337, 'lng':...      4469      95110
# 10  [{'label': 'display', 'lat': 37.3048413, 'lng'...      3551      95125
# 11  [{'label': 'display', 'lat': 37.381694, 'lng':...      5077      95131
# 12  [{'label': 'display', 'lat': 37.318465, 'lng':...      4166      95128
# 13  [{'label': 'display', 'lat': 37.30245971679687...      4367      95125
# 14  [{'label': 'display', 'lat': 37.305084, 'lng':...      4001      95125
# 15  [{'label': 'display', 'lat': 37.327831, 'lng':...      4137      95128
# 16  [{'label': 'display', 'lat': 37.31648254394531...      4323      95128
# 17  [{'label': 'display', 'lat': 37.30323, 'lng': ...      4301      95125
# 18  [{'label': 'display', 'lat': 37.369337, 'lng':...      4469      95110
# 19  [{'label': 'display', 'lat': 37.32184219360351...      4916      95128
# 20  [{'label': 'display', 'lat': 37.306012, 'lng':...      6362      95128
# 21  [{'label': 'display', 'lat': 37.29408264160156...      5313      95125
# 22  [{'label': 'display', 'lat': 37.381694, 'lng':...      5077      95131
# 23  [{'label': 'display', 'lat': 37.31024288558490...      5970      95128
# 24  [{'label': 'display', 'lat': 37.38484573364258...      6073      95131
# 25  [{'label': 'display', 'lat': 37.392659, 'lng':...      6286      95131
# 26  [{'label': 'display', 'lat': 37.393173, 'lng':...      6343      95131
# 27  [{'label': 'display', 'lat': 37.306021, 'lng':...      6362      95128
# 28  [{'label': 'display', 'lat': 37.30582367498474...      6378      95128
# 29  [{'label': 'display', 'lat': 37.30631288980923...      6333        NaN
# 30  [{'label': 'display', 'lat': 37.24814, 'lng': ...     10550        NaN
# 31  [{'label': 'entrance', 'lat': 37.307248, 'lng'...      6222      95128
# 32  [{'label': 'display', 'lat': 37.306119, 'lng':...      6312      95117
# 33  [{'label': 'display', 'lat': 37.3087649451111,...      7428        NaN
# 34  [{'label': 'display', 'lat': 37.31237, 'lng': ...      7661        NaN
#
#     cc      city state        country  \
# 0   US  San Jose    CA  United States
# 1   US  San Jose    CA  United States
# 2   US  San Jose    CA  United States
# 3   US  San Jose    CA  United States
# 4   US  San Jose    CA  United States
# 5   US  San Jose    CA  United States
# 6   US  San Jose    CA  United States
# 7   US  San Jose    CA  United States
# 8   US  San Jose    CA  United States
# 9   US  San Jose    CA  United States
# 10  US  San Jose    CA  United States
# 11  US  San Jose    CA  United States
# 12  US  San Jose    CA  United States
# 13  US  San Jose    CA  United States
# 14  US  San Jose    CA  United States
# 15  US  San Jose    CA  United States
# 16  US  San Jose    CA  United States
# 17  US  San Jose    CA  United States
# 18  US  San Jose    CA  United States
# 19  US  San Jose    CA  United States
# 20  US  San Jose    CA  United States
# 21  US  San Jose    CA  United States
# 22  US  San Jose    CA  United States
# 23  US  San Jose    CA  United States
# 24  US  San Jose    CA  United States
# 25  US  San Jose    CA  United States
# 26  US  San Jose    CA  United States
# 27  US  San Jose    CA  United States
# 28  US  San Jose    CA  United States
# 29  US  San Jose    CA  United States
# 30  US  San Jose    CA  United States
# 31  US  San Jose    CA  United States
# 32  US  San Jose    CA  United States
# 33  US  San Jose    CA  United States
# 34  US  San Jose    CA  United States
#
#                                      formattedAddress     crossStreet  \
# 0   [1520 The Alameda #130, San Jose, CA 95126, Un...             NaN
# 1   [475 N 1st St Ste 200, San Jose, CA 95112, Uni...             NaN
# 2   [259 Meridian Ave Ste 8, San Jose, CA 95126, U...             NaN
# 3   [1630 Oakland Rd Ste A110, San Jose, CA 95131,...             NaN
# 4                 [San Jose, CA 95120, United States]             NaN
# 5   [265 Meridian Ave. #9, San Jose, CA 95126, Uni...             NaN
# 6   [1818 Tully Rd (King Rd), San Jose, CA 95122, ...         King Rd
# 7        [1001 Story RD, San Jose, CA, United States]             NaN
# 8   [259 Meridian Ave Ste 14 (at San Carlos), San ...   at San Carlos
# 9   [1754 Technology Dr Ste 225, San Jose, CA 9511...             NaN
# 10  [1314 Lincoln Ave #2D, San Jose, CA 95125, Uni...             NaN
# 11  [1630 Oakland Rd (Brokaw Rd.), San Jose, CA 95...      Brokaw Rd.
# 12  [527 S Bascom Ave, San Jose, CA 95128, United ...             NaN
# 13  [1670 Westwood Dr Ste J, San Jose, CA 95125, U...             NaN
# 14  [1058 Meridian Ave, San Jose, CA 95125, United...             NaN
# 15                [San Jose, CA 95128, United States]             NaN
# 16  [2211 Moorpark Ave #250 (Bascom), San Jose, CA...          Bascom
# 17                [San Jose, CA 95125, United States]             NaN
# 18  [1754 Technology Dr #128, San Jose, CA 95110, ...             NaN
# 19                [San Jose, CA 95128, United States]             NaN
# 20                [San Jose, CA 95128, United States]             NaN
# 21  [1836 Hamilton Ave (at Grace Ave), San Jose, C...    at Grace Ave
# 22  [1630 Oakland Rd Ste A110 (at Brokaw Road), Sa...  at Brokaw Road
# 23  [860 S Winchester Blvd (at Neal), San Jose, CA...         at Neal
# 24  [2375 Zanker Rd Ste 250, San Jose, CA 95131, U...             NaN
# 25  [1879 Lundy Ave, San Jose, CA 95131, United St...             NaN
# 26  [1885 Lundy Ave, San Jose, CA 95131, United St...             NaN
# 27                [San Jose, CA 95128, United States]             NaN
# 28  [1101 S Winchester Blvd Ste N267, San Jose, CA...             NaN
# 29  [1101 S. Winchester Ste. Ste L239, San Jose, C...             NaN
# 30    [5710 Cahalan Ave, San Jose, CA, United States]             NaN
# 31  [1087 S Winchester Blvd, San Jose, CA 95128, U...             NaN
# 32                [San Jose, CA 95117, United States]             NaN
# 33                      [San Jose, CA, United States]             NaN
# 34                      [San Jose, CA, United States]             NaN
#
#                           id
# 0   4ce1a79ef8a4a1438ddeebbc
# 1   58e178060e0a1e6dd8a4f3e3
# 2   51cb8d6d498e66b4ad36c053
# 3   58f1732e780eee3965948df0
# 4   4f385cc8e4b0571dc87a817b
# 5   5b7a488d791871002c9b8d58
# 6   4c676bfef101ef3bfea376e9
# 7   57faf27e498eb89d33b574ca
# 8   4b429fbdf964a520b4d725e3
# 9   4fe35b50e4b044e6b9b778a3
# 10  5914dd04e97dfb02c922227e
# 11  4dc97c7c1f6e4f316a81f62e
# 12  5a5be6df336273355f0aef86
# 13  5afdca1b838e59002cfcc04a
# 14  4f44327119836ed00192d20d
# 15  4c9a92f69c6637042ee959fd
# 16  578946a3498e611faa0eb158
# 17  5c4cdc2bea1e44002cbebdce
# 18  5960643250a6f05c63317fb9
# 19  4f4eac68e4b09d63cb986f36
# 20  5e28b4a83bd73a0008e835c0
# 21  53ea47d1498ee424dad3c31d
# 22  4c604a05cd522d7f14c0cd3f
# 23  52dfdeaa498ee93fab1cd799
# 24  4e4eed58b0fb088f3c14f8c8
# 25  50fb09f1e4b053e0050d650b
# 26  58a6fd7f4ca49b71b463d664
# 27  5e28b5162e5605000893997b
# 28  54a703b2498e5c3b3605c407
# 29  4e98cb4c55033ea8ab7765ae
# 30  51f432eb498e665b63457d40
# 31  513e495fe4b00cacb03d1860
# 32  4c706206df6b8cfa1f39b84d
# 33  52793b0111d2561d6745f465
# 34  4bdb6160c79cc9281a7c82e9

# %% [markdown]
# There are a few venues with no ZIP codes. Find this information by internet search and fill in the ones that are currently still practicing at the given location. Remove ones who have moved or closed down their business.

# %%
sj_acu_df_filtered.at[7, 'postalCode'] = '95122'
sj_acu_df_filtered.at[30, 'postalCode'] = '95123'
sj_acu_df_filtered.at[33, 'postalCode'] = '95121'

sj_acu_df_filtered.dropna(subset = ['postalCode'], axis = 0, inplace = True)
sj_acu_df_filtered.reset_index(drop = True, inplace = True)
sj_acu_df_filtered
# Out:
#                                                  name          categories  \
# 0                                 Nurture Acupuncture       Acupuncturist
# 1                      Charles Lin Acupuncture Clinic       Acupuncturist
# 2    Acupuncture Orthopedics & Natural Healing Center       Acupuncturist
# 3                                    Numo Acupuncture       Acupuncturist
# 4                                         Acupuncture       Acupuncturist
# 5                                   Green Acupuncture      Massage Studio
# 6                                 Kim Wah Acupuncture       Acupuncturist
# 7              Vinh Quang Acupuncture & Chinese Herbs       Acupuncturist
# 8                                  Lokahi Acupuncture       Acupuncturist
# 9                      Zhu's Neuro-Acupuncture Center       Acupuncturist
# 10                               Red Pine Acupuncture       Acupuncturist
# 11                               Hong Wei Acupuncture       Acupuncturist
# 12                           Alice Acupuncture Center       Acupuncturist
# 13                             AAA Acupuncture Center  Alternative Healer
# 14                          Willow Glen Acupuncture/H       Acupuncturist
# 15                     Cornerstone Acupuncture Center       Acupuncturist
# 16  Victor Cheng Acupuncture and Traditional Chine...       Acupuncturist
# 17                                 Lokahi Acupuncture       Acupuncturist
# 18                         Lao Lao Acupuncture Center       Acupuncturist
# 19        East West Chiropractic & Acupuncture Clinic        Chiropractor
# 20                                  Evoke Acupuncture       Acupuncturist
# 21                        San Jose Acupuncture Center       Acupuncturist
# 22                            Living Room Acupuncture       Acupuncturist
# 23                                 LB Acupuncture inc       Acupuncturist
# 24                                   Park Acupuncture       Acupuncturist
# 25                   Qin Acupuncture and Herbs Center       Acupuncturist
# 26                Lotus Acupuncture & Wellness Center      Medical Center
# 27                                  Evoke Acupuncture       Acupuncturist
# 28                       Natural Wellness Acupuncture       Acupuncturist
# 29                        Acupressure And Acupuncture       Acupuncturist
# 30                                 Valley Acupuncture       Acupuncturist
# 31                                   Zhao Acupuncture       Acupuncturist
# 32                          Peter Hien Vo Acupuncture       Acupuncturist
#
#                             address        lat         lng  \
# 0             1520 The Alameda #130  37.335472 -121.915164
# 1              475 N 1st St Ste 200  37.343643 -121.896553
# 2            259 Meridian Ave Ste 8  37.324388 -121.914624
# 3          1630 Oakland Rd Ste A110  37.381672 -121.894552
# 4                               NaN  37.225533 -121.859755
# 5              265 Meridian Ave. #9  37.324160 -121.914230
# 6                     1818 Tully Rd  37.322895 -121.824707
# 7                     1001 Story RD  37.333230 -121.856727
# 8           259 Meridian Ave Ste 14  37.324516 -121.913934
# 9        1754 Technology Dr Ste 225  37.369337 -121.919080
# 10             1314 Lincoln Ave #2D  37.304841 -121.898004
# 11                  1630 Oakland Rd  37.381694 -121.894485
# 12                 527 S Bascom Ave  37.318465 -121.932040
# 13           1670 Westwood Dr Ste J  37.302460 -121.915771
# 14                1058 Meridian Ave  37.305084 -121.913246
# 15                              NaN  37.327831 -121.936129
# 16           2211 Moorpark Ave #250  37.316483 -121.932671
# 17                              NaN  37.303230 -121.915950
# 18          1754 Technology Dr #128  37.369337 -121.919080
# 19                              NaN  37.321842 -121.943115
# 20                              NaN  37.306012 -121.951616
# 21                1836 Hamilton Ave  37.294083 -121.918839
# 22         1630 Oakland Rd Ste A110  37.381694 -121.894485
# 23            860 S Winchester Blvd  37.310243 -121.949615
# 24           2375 Zanker Rd Ste 250  37.384846 -121.921646
# 25                   1879 Lundy Ave  37.392659 -121.891629
# 26                   1885 Lundy Ave  37.393173 -121.891637
# 27                              NaN  37.306021 -121.951624
# 28  1101 S Winchester Blvd Ste N267  37.305824 -121.951685
# 29                 5710 Cahalan Ave  37.248140 -121.846514
# 30           1087 S Winchester Blvd  37.307213 -121.950691
# 31                              NaN  37.306119 -121.951040
# 32                              NaN  37.308765 -121.814087
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 37.33547199999999...      2177      95126
# 1   [{'label': 'display', 'lat': 37.34364318847656...       983      95112
# 2   [{'label': 'display', 'lat': 37.324388, 'lng':...      2500      95126
# 3   [{'label': 'display', 'lat': 37.3816716, 'lng'...      5075      95131
# 4   [{'label': 'display', 'lat': 37.22553319504755...     12617      95120
# 5   [{'label': 'display', 'lat': 37.32416, 'lng': ...      2484      95126
# 6   [{'label': 'display', 'lat': 37.32289505004883...      6016      95122
# 7   [{'label': 'display', 'lat': 37.33323, 'lng': ...      3014      95122
# 8   [{'label': 'display', 'lat': 37.32451639011752...      2441      95126
# 9   [{'label': 'display', 'lat': 37.369337, 'lng':...      4469      95110
# 10  [{'label': 'display', 'lat': 37.3048413, 'lng'...      3551      95125
# 11  [{'label': 'display', 'lat': 37.381694, 'lng':...      5077      95131
# 12  [{'label': 'display', 'lat': 37.318465, 'lng':...      4166      95128
# 13  [{'label': 'display', 'lat': 37.30245971679687...      4367      95125
# 14  [{'label': 'display', 'lat': 37.305084, 'lng':...      4001      95125
# 15  [{'label': 'display', 'lat': 37.327831, 'lng':...      4137      95128
# 16  [{'label': 'display', 'lat': 37.31648254394531...      4323      95128
# 17  [{'label': 'display', 'lat': 37.30323, 'lng': ...      4301      95125
# 18  [{'label': 'display', 'lat': 37.369337, 'lng':...      4469      95110
# 19  [{'label': 'display', 'lat': 37.32184219360351...      4916      95128
# 20  [{'label': 'display', 'lat': 37.306012, 'lng':...      6362      95128
# 21  [{'label': 'display', 'lat': 37.29408264160156...      5313      95125
# 22  [{'label': 'display', 'lat': 37.381694, 'lng':...      5077      95131
# 23  [{'label': 'display', 'lat': 37.31024288558490...      5970      95128
# 24  [{'label': 'display', 'lat': 37.38484573364258...      6073      95131
# 25  [{'label': 'display', 'lat': 37.392659, 'lng':...      6286      95131
# 26  [{'label': 'display', 'lat': 37.393173, 'lng':...      6343      95131
# 27  [{'label': 'display', 'lat': 37.306021, 'lng':...      6362      95128
# 28  [{'label': 'display', 'lat': 37.30582367498474...      6378      95128
# 29  [{'label': 'display', 'lat': 37.24814, 'lng': ...     10550      95123
# 30  [{'label': 'entrance', 'lat': 37.307248, 'lng'...      6222      95128
# 31  [{'label': 'display', 'lat': 37.306119, 'lng':...      6312      95117
# 32  [{'label': 'display', 'lat': 37.3087649451111,...      7428      95121
#
#     cc      city state        country  \
# 0   US  San Jose    CA  United States
# 1   US  San Jose    CA  United States
# 2   US  San Jose    CA  United States
# 3   US  San Jose    CA  United States
# 4   US  San Jose    CA  United States
# 5   US  San Jose    CA  United States
# 6   US  San Jose    CA  United States
# 7   US  San Jose    CA  United States
# 8   US  San Jose    CA  United States
# 9   US  San Jose    CA  United States
# 10  US  San Jose    CA  United States
# 11  US  San Jose    CA  United States
# 12  US  San Jose    CA  United States
# 13  US  San Jose    CA  United States
# 14  US  San Jose    CA  United States
# 15  US  San Jose    CA  United States
# 16  US  San Jose    CA  United States
# 17  US  San Jose    CA  United States
# 18  US  San Jose    CA  United States
# 19  US  San Jose    CA  United States
# 20  US  San Jose    CA  United States
# 21  US  San Jose    CA  United States
# 22  US  San Jose    CA  United States
# 23  US  San Jose    CA  United States
# 24  US  San Jose    CA  United States
# 25  US  San Jose    CA  United States
# 26  US  San Jose    CA  United States
# 27  US  San Jose    CA  United States
# 28  US  San Jose    CA  United States
# 29  US  San Jose    CA  United States
# 30  US  San Jose    CA  United States
# 31  US  San Jose    CA  United States
# 32  US  San Jose    CA  United States
#
#                                      formattedAddress     crossStreet  \
# 0   [1520 The Alameda #130, San Jose, CA 95126, Un...             NaN
# 1   [475 N 1st St Ste 200, San Jose, CA 95112, Uni...             NaN
# 2   [259 Meridian Ave Ste 8, San Jose, CA 95126, U...             NaN
# 3   [1630 Oakland Rd Ste A110, San Jose, CA 95131,...             NaN
# 4                 [San Jose, CA 95120, United States]             NaN
# 5   [265 Meridian Ave. #9, San Jose, CA 95126, Uni...             NaN
# 6   [1818 Tully Rd (King Rd), San Jose, CA 95122, ...         King Rd
# 7        [1001 Story RD, San Jose, CA, United States]             NaN
# 8   [259 Meridian Ave Ste 14 (at San Carlos), San ...   at San Carlos
# 9   [1754 Technology Dr Ste 225, San Jose, CA 9511...             NaN
# 10  [1314 Lincoln Ave #2D, San Jose, CA 95125, Uni...             NaN
# 11  [1630 Oakland Rd (Brokaw Rd.), San Jose, CA 95...      Brokaw Rd.
# 12  [527 S Bascom Ave, San Jose, CA 95128, United ...             NaN
# 13  [1670 Westwood Dr Ste J, San Jose, CA 95125, U...             NaN
# 14  [1058 Meridian Ave, San Jose, CA 95125, United...             NaN
# 15                [San Jose, CA 95128, United States]             NaN
# 16  [2211 Moorpark Ave #250 (Bascom), San Jose, CA...          Bascom
# 17                [San Jose, CA 95125, United States]             NaN
# 18  [1754 Technology Dr #128, San Jose, CA 95110, ...             NaN
# 19                [San Jose, CA 95128, United States]             NaN
# 20                [San Jose, CA 95128, United States]             NaN
# 21  [1836 Hamilton Ave (at Grace Ave), San Jose, C...    at Grace Ave
# 22  [1630 Oakland Rd Ste A110 (at Brokaw Road), Sa...  at Brokaw Road
# 23  [860 S Winchester Blvd (at Neal), San Jose, CA...         at Neal
# 24  [2375 Zanker Rd Ste 250, San Jose, CA 95131, U...             NaN
# 25  [1879 Lundy Ave, San Jose, CA 95131, United St...             NaN
# 26  [1885 Lundy Ave, San Jose, CA 95131, United St...             NaN
# 27                [San Jose, CA 95128, United States]             NaN
# 28  [1101 S Winchester Blvd Ste N267, San Jose, CA...             NaN
# 29    [5710 Cahalan Ave, San Jose, CA, United States]             NaN
# 30  [1087 S Winchester Blvd, San Jose, CA 95128, U...             NaN
# 31                [San Jose, CA 95117, United States]             NaN
# 32                      [San Jose, CA, United States]             NaN
#
#                           id
# 0   4ce1a79ef8a4a1438ddeebbc
# 1   58e178060e0a1e6dd8a4f3e3
# 2   51cb8d6d498e66b4ad36c053
# 3   58f1732e780eee3965948df0
# 4   4f385cc8e4b0571dc87a817b
# 5   5b7a488d791871002c9b8d58
# 6   4c676bfef101ef3bfea376e9
# 7   57faf27e498eb89d33b574ca
# 8   4b429fbdf964a520b4d725e3
# 9   4fe35b50e4b044e6b9b778a3
# 10  5914dd04e97dfb02c922227e
# 11  4dc97c7c1f6e4f316a81f62e
# 12  5a5be6df336273355f0aef86
# 13  5afdca1b838e59002cfcc04a
# 14  4f44327119836ed00192d20d
# 15  4c9a92f69c6637042ee959fd
# 16  578946a3498e611faa0eb158
# 17  5c4cdc2bea1e44002cbebdce
# 18  5960643250a6f05c63317fb9
# 19  4f4eac68e4b09d63cb986f36
# 20  5e28b4a83bd73a0008e835c0
# 21  53ea47d1498ee424dad3c31d
# 22  4c604a05cd522d7f14c0cd3f
# 23  52dfdeaa498ee93fab1cd799
# 24  4e4eed58b0fb088f3c14f8c8
# 25  50fb09f1e4b053e0050d650b
# 26  58a6fd7f4ca49b71b463d664
# 27  5e28b5162e5605000893997b
# 28  54a703b2498e5c3b3605c407
# 29  51f432eb498e665b63457d40
# 30  513e495fe4b00cacb03d1860
# 31  4c706206df6b8cfa1f39b84d
# 32  52793b0111d2561d6745f465

# %% [markdown]
# Calculate the number of venues in each neighborhood (ZIP code)

# %%
sj_acu_zip = sj_acu_df_filtered.groupby('postalCode').count()
sj_acu_zip['Zipcode'] = sj_acu_zip.index
sj_acu_zip
# Out:
#             name  categories  address  lat  lng  labeledLatLngs  distance  cc  \
# postalCode
# 95110          2           2        2    2    2               2         2   2
# 95112          1           1        1    1    1               1         1   1
# 95117          1           1        0    1    1               1         1   1
# 95120          1           1        0    1    1               1         1   1
# 95121          1           1        0    1    1               1         1   1
# 95122          2           2        2    2    2               2         2   2
# 95123          1           1        1    1    1               1         1   1
# 95125          5           5        4    5    5               5         5   5
# 95126          4           4        4    4    4               4         4   4
# 95128          9           9        5    9    9               9         9   9
# 95131          6           6        6    6    6               6         6   6
#
#             city  state  country  formattedAddress  crossStreet  id Zipcode
# postalCode
# 95110          2      2        2                 2            0   2   95110
# 95112          1      1        1                 1            0   1   95112
# 95117          1      1        1                 1            0   1   95117
# 95120          1      1        1                 1            0   1   95120
# 95121          1      1        1                 1            0   1   95121
# 95122          2      2        2                 2            1   2   95122
# 95123          1      1        1                 1            0   1   95123
# 95125          5      5        5                 5            1   5   95125
# 95126          4      4        4                 4            1   4   95126
# 95128          9      9        9                 9            2   9   95128
# 95131          6      6        6                 6            2   6   95131

# %%
sj_acu_zip = sj_acu_zip[['Zipcode', 'name']]
sj_acu_zip['Zipcode'] = sj_acu_zip['Zipcode'].astype(int)

sj_acu_zip.sort_values(by = 'Zipcode', inplace = True)
sj_acu_zip.columns = ['Zipcode', 'numbers']

#sj_acu_zip.reset_index(drop = True, inplace = True)
sj_acu_zip
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#             Zipcode  numbers
# postalCode
# 95110         95110        2
# 95112         95112        1
# 95117         95117        1
# 95120         95120        1
# 95121         95121        1
# 95122         95122        2
# 95123         95123        1
# 95125         95125        5
# 95126         95126        4
# 95128         95128        9
# 95131         95131        6

# %% [markdown]
# Add this data into the existing dataframe

# %%
sj_zip_wages_df['NumAcuClinics'] = ""

count = 0

for zipcode in sj_zip_wages_df['Zipcode']:
    
    if zipcode in list(sj_acu_zip['Zipcode']):
       # print(zip, " is in the list")
        
        list_index = list(sj_acu_zip['Zipcode']).index(zipcode)
              
        sj_zip_wages_df.at[count, 'NumAcuClinics'] = sj_acu_zip.iloc[list_index]['numbers']
    else:
        # print(zip, " is not in the list")
        
        sj_zip_wages_df.at[count, 'NumAcuClinics'] = 0
        
    count = count + 1

# %%
sj_zip_wages_df
# Out:
#     Zipcode    Lat    Long  EstimatedPopulation    TotalWages  PerCapitaWages  \
# 0     95110  37.34 -121.90              12621.0  3.664686e+08    29036.412963
# 1     95111  37.28 -121.83              43578.0  8.660207e+08    19872.887374
# 2     95112  37.34 -121.88              34111.0  8.917957e+08    26143.931606
# 3     95113  37.33 -121.89               1049.0  3.792411e+07    36152.631077
# 4     95116  37.35 -121.85              35357.0  6.238882e+08    17645.394519
# 5     95117  37.31 -121.96              22030.0  6.661914e+08    30240.189696
# 6     95118  37.25 -121.88              26249.0  8.777164e+08    33438.090632
# 7     95119  37.22 -121.78               8171.0  2.887622e+08    35339.883368
# 8     95120  37.19 -121.83              33486.0  1.704123e+09    50890.606821
# 9     95121  37.30 -121.80              30427.0  7.641766e+08    25115.081638
# 10    95122  37.33 -121.83              41936.0  7.011536e+08    16719.609953
# 11    95123  37.23 -121.82              50481.0  1.634682e+09    32382.124086
# 12    95124  37.25 -121.92              39234.0  1.515281e+09    38621.629938
# 13    95125  37.29 -121.88              41048.0  1.782530e+09    43425.502022
# 14    95126  37.32 -121.91              23076.0  8.414504e+08    36464.311362
# 15    95127  37.37 -121.75              46641.0  1.064356e+09    22820.174160
# 16    95128  37.31 -121.93              25327.0  8.363117e+08    33020.557231
# 17    95129  37.30 -122.00              32839.0  1.371049e+09    41750.644569
# 18    95130  37.28 -121.98              10841.0  3.945737e+08    36396.430311
# 19    95131  37.38 -121.90              24403.0  9.194561e+08    37677.994919
# 20    95132  37.42 -121.77              34344.0  1.054567e+09    30705.994118
# 21    95133  37.37 -121.86              20337.0  5.406107e+08    26582.617544
# 22    95134  37.42 -121.94              12670.0  6.541769e+08    51631.955722
# 23    95135  37.25 -121.67              17221.0  7.246593e+08    42079.977063
# 24    95136  37.27 -121.84              35078.0  1.177501e+09    33568.082074
# 25    95138  37.24 -121.73              15421.0  8.911679e+08    57789.241554
# 26    95139  37.21 -121.75               5634.0  2.056586e+08    36503.131523
# 27    95148  37.33 -121.77              37541.0  1.141396e+09    30403.984470
#
#    NumAcuClinics
# 0              2
# 1              0
# 2              1
# 3              0
# 4              0
# 5              1
# 6              0
# 7              0
# 8              1
# 9              1
# 10             2
# 11             1
# 12             0
# 13             5
# 14             4
# 15             0
# 16             9
# 17             0
# 18             0
# 19             6
# 20             0
# 21             0
# 22             0
# 23             0
# 24             0
# 25             0
# 26             0
# 27             0

# %% [markdown]
# ### 3.3 Crime Rate, Unemployment Rate, Bachelor Degree Percentage, Median Home Price

# %% [markdown]
# Import remaining data from manually tabulated Excel spreadsheet

# %%
sj_other_data_df = pd.read_excel('San_Jose_Other_Data.xlsx')
sj_other_data_df.head()
# Out:
#    Zipcode  Crime_rate  Unemployment_Rate_25  Bachelor_Degree_Percentage  \
# 0    95110          91                   4.9                        32.4
# 1    95111          32                   6.1                        19.6
# 2    95112          85                   6.2                        35.0
# 3    95113          86                   4.5                        72.8
# 4    95116          37                   6.9                        16.6
#
#    Median_Home_Zillow
# 0                 820
# 1                 774
# 2                 849
# 3                 763
# 4                 712

# %% [markdown]
# ### 3.4 Final Data Aggregation

# %% [markdown]
# Combine data from all the previous sections. Remove TotalWages and keep only PerCapitaWages

# %%
sj_zip_merged_df = sj_zip_wages_df
sj_zip_merged_df = sj_zip_merged_df.join(sj_other_data_df.set_index('Zipcode'), on='Zipcode')
sj_zip_merged_df.columns = ['Zipcode', 'Lat','Long','EstPop', 'TotalWages', 'PerCapitaWages', 'Clinics', 'CrimeRate', 'UnemployRate', 
                           'BSPercent', 'HomePrice']

sj_zip_merged_df.drop(['TotalWages'], axis = 1, inplace = True)
sj_zip_merged_df.head()
# Out:
#    Zipcode    Lat    Long   EstPop  PerCapitaWages Clinics  CrimeRate  \
# 0    95110  37.34 -121.90  12621.0    29036.412963       2         91
# 1    95111  37.28 -121.83  43578.0    19872.887374       0         32
# 2    95112  37.34 -121.88  34111.0    26143.931606       1         85
# 3    95113  37.33 -121.89   1049.0    36152.631077       0         86
# 4    95116  37.35 -121.85  35357.0    17645.394519       0         37
#
#    UnemployRate  BSPercent  HomePrice
# 0           4.9       32.4        820
# 1           6.1       19.6        774
# 2           6.2       35.0        849
# 3           4.5       72.8        763
# 4           6.9       16.6        712

# %% [markdown]
# ### 3.4 Clustering Modeling

# %% [markdown]
# Transform data by normalizing the columns with the StandardScaler.

# %%
#from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

X = sj_zip_merged_df[['EstPop', 'PerCapitaWages', 'Clinics', 'CrimeRate', 'UnemployRate', 'BSPercent', 'HomePrice']]
#sj_zip_transformed = MinMaxScaler().fit_transform(X)
sj_zip_transformed = StandardScaler().fit_transform(X)
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype int64, float64, object were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/sklearn/base.py:462: DataConversionWarning: Data with input dtype int64, float64, object were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %% [markdown]
# Run k-means clustering algorithm

# %%
# set number of clusters
kclusters = 5

# run k-means clustering
#kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(sj_zip_transformed)
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(sj_zip_transformed)

# check cluster labels generated for each row in the dataframe
#kmeans.labels_[0:10] 

print("Cluster Labels:")
print(kmeans.labels_)
# Out:
# Cluster Labels:
# [1 4 1 2 4 1 1 2 3 4 4 1 1 0 0 4 0 3 3 0 1 4 2 2 1 3 1 1]

# %% [markdown]
# ## 4. Results
# <a id = "results"></a>

# %% [markdown]
# Insert resulting cluster labels back into merged dataframe

# %%
sj_zip_merged_df.insert(1, 'Cluster Labels', kmeans.labels_)

# Uncomment following code if trying to re-run this individual code. 
# As cannot reinsert existing column. 
# sj_zip_merged_df['Cluster Labels'] = kmeans.labels_

sj_zip_merged_df.head()
# Out:
#    Zipcode  Cluster Labels    Lat    Long   EstPop  PerCapitaWages Clinics  \
# 0    95110               1  37.34 -121.90  12621.0    29036.412963       2
# 1    95111               4  37.28 -121.83  43578.0    19872.887374       0
# 2    95112               1  37.34 -121.88  34111.0    26143.931606       1
# 3    95113               2  37.33 -121.89   1049.0    36152.631077       0
# 4    95116               4  37.35 -121.85  35357.0    17645.394519       0
#
#    CrimeRate  UnemployRate  BSPercent  HomePrice
# 0         91           4.9       32.4        820
# 1         32           6.1       19.6        774
# 2         85           6.2       35.0        849
# 3         86           4.5       72.8        763
# 4         37           6.9       16.6        712

# %% [markdown]
# Re-draw San Jose map with color-code clustering labels

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(sj_zip_merged_df['Lat'], sj_zip_merged_df['Long'], sj_zip_merged_df['Zipcode'], sj_zip_merged_df['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Let's begin with Cluster 1, which has the most neighborhoods

# %%
sj_zip_merged_df.loc[sj_zip_merged_df['Cluster Labels'] == 1, 
                   sj_zip_merged_df.columns[[0] + list(range(4, sj_zip_merged_df.shape[1]))]]
# Out:
#     Zipcode   EstPop  PerCapitaWages Clinics  CrimeRate  UnemployRate  \
# 0     95110  12621.0    29036.412963       2         91           4.9
# 2     95112  34111.0    26143.931606       1         85           6.2
# 5     95117  22030.0    30240.189696       1         21           5.5
# 6     95118  26249.0    33438.090632       0         65           4.3
# 11    95123  50481.0    32382.124086       1         67           4.0
# 12    95124  39234.0    38621.629938       0         69           4.4
# 20    95132  34344.0    30705.994118       0         65           5.9
# 24    95136  35078.0    33568.082074       0         68           4.7
# 26    95139   5634.0    36503.131523       0         40           6.2
# 27    95148  37541.0    30403.984470       0         61           5.7
#
#     BSPercent  HomePrice
# 0        32.4        820
# 2        35.0        849
# 5        45.5       1275
# 6        46.6       1128
# 11       41.1        946
# 12       53.0       1275
# 20       45.7       1151
# 24       46.7        961
# 26       47.7        904
# 27       39.0       1026

# %% [markdown]
# In this cluster, it appears that all the parameters such as per capita wages, unemployment, bachelor degree percentage, and home prices, are average, neither too high nor too low. The number of clinics here are also very sparse.

# %% [markdown]
# Let's continue to examine Cluster 4, which has the 2nd most neighborhoods.

# %%
sj_zip_merged_df.loc[sj_zip_merged_df['Cluster Labels'] == 4, 
                   sj_zip_merged_df.columns[[0] + list(range(4, sj_zip_merged_df.shape[1]))]]
# Out:
#     Zipcode   EstPop  PerCapitaWages Clinics  CrimeRate  UnemployRate  \
# 1     95111  43578.0    19872.887374       0         32           6.1
# 4     95116  35357.0    17645.394519       0         37           6.9
# 9     95121  30427.0    25115.081638       1         59           6.0
# 10    95122  41936.0    16719.609953       2         29           6.4
# 15    95127  46641.0    22820.174160       0         45           5.5
# 21    95133  20337.0    26582.617544       0         24           7.3
#
#     BSPercent  HomePrice
# 1        19.6        774
# 4        16.6        712
# 9        29.6        852
# 10       15.1        726
# 15       23.4        792
# 21       35.3        870

# %% [markdown]
# Cluster 4 does not appear to be wealthy, with lower wages and home prices. The unemployment rate is higher, and the bachelor degree percentage is low. The crime rate is low, a result that may run a bit counterintuitive. There is not a lot of existing competition, as the number of clinics is sparse as well.

# %% [markdown]
# Let's examine the remaining clusters, which have 4 neighborhoods each. We will start with Cluster 0

# %%
sj_zip_merged_df.loc[sj_zip_merged_df['Cluster Labels'] == 0, 
                   sj_zip_merged_df.columns[[0] + list(range(4, sj_zip_merged_df.shape[1]))]]
# Out:
#     Zipcode   EstPop  PerCapitaWages Clinics  CrimeRate  UnemployRate  \
# 13    95125  41048.0    43425.502022       5         92           4.8
# 14    95126  23076.0    36464.311362       4         93           4.8
# 16    95128  25327.0    33020.557231       9         80           3.6
# 19    95131  24403.0    37677.994919       6         55           4.4
#
#     BSPercent  HomePrice
# 13       54.0       1331
# 14       52.0       1025
# 16       43.8       1159
# 19       55.9       1077

# %% [markdown]
# This is an affluent cluster, with the high per capita wages and home prices. The unemployment rate is also low, as expected. The crime rate is rather high for this area. However, the biggest observation is the stiff competition, with a large number of existing clinics.

# %% [markdown]
# Next We will examine Cluster 2.

# %%
sj_zip_merged_df.loc[sj_zip_merged_df['Cluster Labels'] == 2, 
                   sj_zip_merged_df.columns[[0] + list(range(4, sj_zip_merged_df.shape[1]))]]
# Out:
#     Zipcode   EstPop  PerCapitaWages Clinics  CrimeRate  UnemployRate  \
# 3     95113   1049.0    36152.631077       0         86           4.5
# 7     95119   8171.0    35339.883368       0        128           4.2
# 22    95134  12670.0    51631.955722       0         92           3.0
# 23    95135  17221.0    42079.977063       0        121           4.7
#
#     BSPercent  HomePrice
# 3        72.8        763
# 7        41.5        953
# 22       75.8        951
# 23       61.3       1169

# %% [markdown]
# This cluster is wealthy and highly educated, with low unemployment rates. The home prices are not as high, which may indicate an area that is still growing. There is also no competition in this area either. However, the recorded crime rate is high.

# %% [markdown]
# Lastly, let's look at Cluster 3

# %%
sj_zip_merged_df.loc[sj_zip_merged_df['Cluster Labels'] == 3, 
                   sj_zip_merged_df.columns[[0] + list(range(4, sj_zip_merged_df.shape[1]))]]
# Out:
#     Zipcode   EstPop  PerCapitaWages Clinics  CrimeRate  UnemployRate  \
# 8     95120  33486.0    50890.606821       1         52           3.1
# 17    95129  32839.0    41750.644569       0         53           3.7
# 18    95130  10841.0    36396.430311       0         64           3.7
# 25    95138  15421.0    57789.241554       0         42           5.3
#
#     BSPercent  HomePrice
# 8        71.3       1508
# 17       72.9       1751
# 18       55.7       1419
# 25       59.2       1213

# %% [markdown]
# This cluster appears to be the wealthiest, both in terms of wages and home prices. This cluster is also highly educated with high bachelor degree percentages, along with low unemployment rates and low crime rates. The existing competition is also very weak, with only 1 clinic in the entire cluster.

# %% [markdown]
# ## 5. Discussion
# <a id = "discussion"></a>

# %% [markdown]
# From the results of the previous section, it is reasonable to avoid setting up a clinic in Cluster 0. The biggest drawback is existing stiff competition, and the high saturation can be a challenge getting the business off the ground, in addition to future business growth.
#
# Another cluster that I would advise against would be Cluster 4. Despite weak competition and low crime rate, the neighborhoods are not wealthy, with higher unemployment rates. This is not an ideal location to place your business in.
#
# As for Cluster 1, whose attributes are average, these neighborhoods probably would be considered a "safe bet" and recommended over Clusters 0 and 4.
#
# However, it is also possible to do better by examining the results of Clusters 2 and 3. Both are affluent and highly educated, with weak competition. The downside to Cluster 2 is the high recorded crime rate. The lower home prices may or may not be a reflection of that. It can also indicate that it is a neighborhood currently under growth.
#
# Based on the findings of the data, we can conclude that Cluster 3 contains the neighborhoods with conditions most favorable to start an acupuncture clinic in.

# %% [markdown]
# ## 6. Conclusion
# <a id = "conclusion"></a>

# %% [markdown]
# This project provided me an opportunity to compile, analyze, and process demographic data of real neighborhoods. The work was done under the context of finding a suitable business location for an acupuncture clinic. The parameters I inspected was population, per capita wages, acupuncture clinics in the neighborhood, crime rate, unemployment rate (over 25), bachelor degree percentage (over 25), and median home price.
#
# This data was further analyzed using the k-means clustering algorithm, where its results helped provide insight on which neighborhoods would be most ideal to setup an acupuncture practice.
#
# There are a few other things worth pointing out about the model's findings that could serve as future directions. The first is that average commercial rent prices were not included in the model, which may be an important deciding factor. For example, a wealthier neighborhood may also charge higher commercial rent, which can be a deterrent for setting up a business there. The second is that Foursquare location data only returns 50 results for a venue search. Based on personal experience residing in this area, the number of acupuncture clinics reported is lower than expected. This factor affects the accuracy of the model. Lastly, using the total crime rate may not give the entire picture either. Violent crimes tend to discourage starting a business in the area, while the impact of lesser crimes can be much lower.
#
# Despite this, the findings of this project are valuable and provide a good starting point for further analysis.
